# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
import pandas as pd
import os

# List files in the current directory
print(os.listdir())  # This will show you the exact file name in your current directory

# Load data
df = pd.read_csv("Student_performance_data .csv")  # Ensure the file name matches the exact one from os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Student_performance_data .csv', 'Univariate Analysis.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
# Load data
df = pd.read_csv("Student_performance_data .csv")

# %%
# Only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# %%
# Compute correlations
corr = numeric_df.corr()

# %%
# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix')
plt.show()
